# %%
# import glob
# glob.__file__
# '/opt/anaconda3/lib/python3.7/glob.py'

# %%
from glob import glob
glob('gaussian_filtered_images/Mild/*')
# Out:
# ['gaussian_filtered_images/Mild/8bbd7835e9aa.png',
#  'gaussian_filtered_images/Mild/d85d052900b4.png',
#  'gaussian_filtered_images/Mild/fecf4c5ae84b.png',
#  'gaussian_filtered_images/Mild/0a3202889f4d.png',
#  'gaussian_filtered_images/Mild/e55188915f9d.png',
#  'gaussian_filtered_images/Mild/6298468d7d75.png',
#  'gaussian_filtered_images/Mild/58184d6fd087.png',
#  'gaussian_filtered_images/Mild/03e25101e8e8.png',
#  'gaussian_filtered_images/Mild/80a02014b418.png',
#  'gaussian_filtered_images/Mild/76be29bb30b2.png',
#  'gaussian_filtered_images/Mild/5712e2aa73a2.png',
#  'gaussian_filtered_images/Mild/200d947f75db.png',
#  'gaussian_filtered_images/Mild/db4ed1e07aa3.png',
#  'gaussian_filtered_images/Mild/8f2996b8d855.png',
#  'gaussian_filtered_images/Mild/94372043d55b.png',
#  'gaussian_filtered_images/Mild/7427dedafccf.png',
#  'gaussian_filtered_images/Mild/6c6efb6b1358.png',
#  'gaussian_filtered_images/Mild/2ecbc2e3f239.png',
#  'gaussian_filtered_images/Mild/06b71823f9cd.png',
#  'gaussian_filtered_images/Mild/5090917a2676.png',
#  'gaussian_filtered_images/Mild/8fc09fecd22f.png',
#  'gaussian_filtered_images/Mild/1d11794057ff.png',
#  'gaussian_filtered_images/Mild/4ecd1fdd1435.png',
#  'gaussian_filtered_images/Mild/172df1330a60.png',
#  'gaussian_filtered_images/Mild/c1e6fa1ad314.png',
#  'gaussian_filtered_images/Mild/8dc22e65c06f.png',
#  'gaussian_filtered_images/Mild/80d24897669f.png',
#  'gaussian_filtered_images/Mild/1a03a7970337.png',
#  'gaussian_filtered_images/Mild/fca931da5c5e.png',
#  'gaussian_filtered_images/Mild/82ac8463fadd.png',
#  'gaussian_filtered_images/Mild/0124dffecf29.png',
#  'gaussian_filtered_images/Mild/3f73c91b7e32.png',
#  'gaussian_filtered_images/Mild/1bb0ddfe753a.png',
#  'gaussian_filtered_images/Mild/b4f41b5bf0ef.png',
#  'gaussian_filtered_images/Mild/da1fb35f5df9.png',
#  'gaussian_filtered_images/Mild/19e350c7c83c.png',
#  'gaussian_filtered_images/Mild/0024cdab0c1e.png',
#  'gaussian_filtered_images/Mild/7ae69d22075a.png',
#  'gaussian_filtered_images/Mild/b9b99dad668d.png',
#  'gaussian_filtered_images/Mild/2d9d97a6e713.png',
#  'gaussian_filtered_images/Mild/a8c950a99107.png',
#  'gaussian_filtered_images/Mild/33b893e18eb3.png',
#  'gaussian_filtered_images/Mild/7b20210d9120.png',
#  'gaussian_filtered_images/Mild/5633ced07d8e.png',
#  'gaussian_filtered_images/Mild/7ef5ff774a48.png',
#  'gaussian_filtered_images/Mild/24b943fe725e.png',
#  'gaussian_filtered_images/Mild/b7278b4f2448.png',
#  'gaussian_filtered_images/Mild/2f4e81787d9b.png',
#  'gaussian_filtered_images/Mild/a32886cb31ab.png',
#  'gaussian_filtered_images/Mild/3c72f580d4ba.png',
#  'gaussian_filtered_images/Mild/944a233fbf8e.png',
#  'gaussian_filtered_images/Mild/63a03880939c.png',
#  'gaussian_filtered_images/Mild/b1197f2cc9b3.png',
#  'gaussian_filtered_images/Mild/a00b4cb250a7.png',
#  'gaussian_filtered_images/Mild/977e1ca77653.png',
#  'gaussian_filtered_images/Mild/278aa860dffd.png',
#  'gaussian_filtered_images/Mild/89ed6a0dd53f.png',
#  'gaussian_filtered_images/Mild/8a01daa423f7.png',
#  'gaussian_filtered_images/Mild/cd45bfa07d41.png',
#  'gaussian_filtered_images/Mild/a8582e346df0.png',
#  'gaussian_filtered_images/Mild/8273fdb4405e.png',
#  'gaussian_filtered_images/Mild/086d41d17da8.png',
#  'gaussian_filtered_images/Mild/71c1a3cdbe47.png',
#  'gaussian_filtered_images/Mild/e38f3a65b02b.png',
#  'gaussian_filtered_images/Mild/9782c0489eca.png',
#  'gaussian_filtered_images/Mild/4a213b405ee4.png',
#  'gaussian_filtered_images/Mild/a19ecd0a706e.png',
#  'gaussian_filtered_images/Mild/b8ebedd382de.png',
#  'gaussian_filtered_images/Mild/83e529e95b0e.png',
#  'gaussian_filtered_images/Mild/10f36b0239fb.png',
#  'gaussian_filtered_images/Mild/6377e23928f6.png',
#  'gaussian_filtered_images/Mild/5777ef74c9ec.png',
#  'gaussian_filtered_images/Mild/a8c54e2a4b79.png',
#  'gaussian_filtered_images/Mild/fea14b3d44b0.png',
#  'gaussian_filtered_images/Mild/c0968d41eb93.png',
#  'gaussian_filtered_images/Mild/2994f17f58a5.png',
#  'gaussian_filtered_images/Mild/3461dc601cc2.png',
#  'gaussian_filtered_images/Mild/4f7755e74a9e.png',
#  'gaussian_filtered_images/Mild/ad3fc5076852.png',
#  'gaussian_filtered_images/Mild/1d674e2e32e0.png',
#  'gaussian_filtered_images/Mild/111898ab463d.png',
#  'gaussian_filtered_images/Mild/52ae917fcea4.png',
#  'gaussian_filtered_images/Mild/94111ed3d276.png',
#  'gaussian_filtered_images/Mild/4ef7144e24ff.png',
#  'gaussian_filtered_images/Mild/66cd9c28e636.png',
#  'gaussian_filtered_images/Mild/9eaf735cf01f.png',
#  'gaussian_filtered_images/Mild/cb2f3c5d71a7.png',
#  'gaussian_filtered_images/Mild/93be637084a2.png',
#  'gaussian_filtered_images/Mild/6165081b9021.png',
#  'gaussian_filtered_images/Mild/358d2224de73.png',
#  'gaussian_filtered_images/Mild/3c726de3ee90.png',
#  'gaussian_filtered_images/Mild/28f98cfe3858.png',
#  'gaussian_filtered_images/Mild/259d30f693b6.png',
#  'gaussian_filtered_images/Mild/f0c13be90519.png',
#  'gaussian_filtered_images/Mild/4d7d6928534a.png',
#  'gaussian_filtered_images/Mild/ea15a290eb96.png',
#  'gaussian_filtered_images/Mild/7bf981d9c7fe.png',
#  'gaussian_filtered_images/Mild/f481f76a6b75.png',
#  'gaussian_filtered_images/Mild/59e5212f7139.png',
#  'gaussian_filtered_images/Mild/9ed666e982cd.png',
#  'gaussian_filtered_images/Mild/ca6842bfcbc9.png',
#  'gaussian_filtered_images/Mild/bb45257258cc.png',
#  'gaussian_filtered_images/Mild/5671eb95512b.png',
#  'gaussian_filtered_images/Mild/c40976189f22.png',
#  'gaussian_filtered_images/Mild/77a9538b8362.png',
#  'gaussian_filtered_images/Mild/ef8109305128.png',
#  'gaussian_filtered_images/Mild/95a4cc805c7b.png',
#  'gaussian_filtered_images/Mild/4aa07d720638.png',
#  'gaussian_filtered_images/Mild/4029d70e9d8a.png',
#  'gaussian_filtered_images/Mild/a77dbec966d4.png',
#  'gaussian_filtered_images/Mild/e9286ddf6ffe.png',
#  'gaussian_filtered_images/Mild/bb9a3d835a94.png',
#  'gaussian_filtered_images/Mild/15cc2aef772a.png',
#  'gaussian_filtered_images/Mild/d567a1a22d33.png',
#  'gaussian_filtered_images/Mild/4fa26d065ad3.png',
#  'gaussian_filtered_images/Mild/09935d72892b.png',
#  'gaussian_filtered_images/Mild/1c0cf251b426.png',
#  'gaussian_filtered_images/Mild/3dbc90c7ee7d.png',
#  'gaussian_filtered_images/Mild/30cab14951ac.png',
#  'gaussian_filtered_images/Mild/d0d59ed675b5.png',
#  'gaussian_filtered_images/Mild/3de8ad4151e1.png',
#  'gaussian_filtered_images/Mild/bb11db08584a.png',
#  'gaussian_filtered_images/Mild/ad1f7445b1a8.png',
#  'gaussian_filtered_images/Mild/595446774178.png',
#  'gaussian_filtered_images/Mild/49c5e7f6b8d2.png',
#  'gaussian_filtered_images/Mild/0dce95217626.png',
#  'gaussian_filtered_images/Mild/cf603a9ef2d5.png',
#  'gaussian_filtered_images/Mild/a5a2a7003d60.png',
#  'gaussian_filtered_images/Mild/47d1603a555b.png',
#  'gaussian_filtered_images/Mild/a7ec056502e7.png',
#  'gaussian_filtered_images/Mild/2f2e1949ad56.png',
#  'gaussian_filtered_images/Mild/51131b48f9d4.png',
#  'gaussian_filtered_images/Mild/b640e3bdff75.png',
#  'gaussian_filtered_images/Mild/582115961a3d.png',
#  'gaussian_filtered_images/Mild/ca30a97e9d13.png',
#  'gaussian_filtered_images/Mild/0a61bddab956.png',
#  'gaussian_filtered_images/Mild/4dd5d5ccddcf.png',
#  'gaussian_filtered_images/Mild/5548a7961a3e.png',
#  'gaussian_filtered_images/Mild/71f6a6e4620a.png',
#  'gaussian_filtered_images/Mild/c96f743915b5.png',
#  'gaussian_filtered_images/Mild/b71428739d4e.png',
#  'gaussian_filtered_images/Mild/f72ef9ceeaa8.png',
#  'gaussian_filtered_images/Mild/9a3109657ac1.png',
#  'gaussian_filtered_images/Mild/8714d17bb6da.png',
#  'gaussian_filtered_images/Mild/2d7666b8884f.png',
#  'gaussian_filtered_images/Mild/1df3e03a8f5f.png',
#  'gaussian_filtered_images/Mild/5879285f9d8d.png',
#  'gaussian_filtered_images/Mild/7347f5133a6a.png',
#  'gaussian_filtered_images/Mild/5b068765e846.png',
#  'gaussian_filtered_images/Mild/0fb1053285cf.png',
#  'gaussian_filtered_images/Mild/c7b622ec8104.png',
#  'gaussian_filtered_images/Mild/bebb3f167654.png',
#  'gaussian_filtered_images/Mild/5b804948e35f.png',
#  'gaussian_filtered_images/Mild/578109578b46.png',
#  'gaussian_filtered_images/Mild/523b3f0fc646.png',
#  'gaussian_filtered_images/Mild/c739ff9580d3.png',
#  'gaussian_filtered_images/Mild/78bcdffb8785.png',
#  'gaussian_filtered_images/Mild/6762b2b48ea5.png',
#  'gaussian_filtered_images/Mild/63363410389a.png',
#  'gaussian_filtered_images/Mild/c56e65f74187.png',
#  'gaussian_filtered_images/Mild/d6e26fe51dce.png',
#  'gaussian_filtered_images/Mild/38e0e28d35d3.png',
#  'gaussian_filtered_images/Mild/b17f0b81dab3.png',
#  'gaussian_filtered_images/Mild/545df1bbcd61.png',
#  'gaussian_filtered_images/Mild/384631079d1e.png',
#  'gaussian_filtered_images/Mild/101b9ebfc720.png',
#  'gaussian_filtered_images/Mild/4c3c1ed09771.png',
#  'gaussian_filtered_images/Mild/4e6071b73120.png',
#  'gaussian_filtered_images/Mild/a28bfb772f50.png',
#  'gaussian_filtered_images/Mild/a443c4fd489c.png',
#  'gaussian_filtered_images/Mild/059bc89df7f4.png',
#  'gaussian_filtered_images/Mild/2a08ed6bbcbc.png',
#  'gaussian_filtered_images/Mild/db690e2d02f8.png',
#  'gaussian_filtered_images/Mild/0ad7f631dedb.png',
#  'gaussian_filtered_images/Mild/f7fec8935126.png',
#  'gaussian_filtered_images/Mild/bd269a1f0e4d.png',
#  'gaussian_filtered_images/Mild/e96bd80a8a53.png',
#  'gaussian_filtered_images/Mild/35aa7f5c2ec0.png',
#  'gaussian_filtered_images/Mild/55eac26bd383.png',
#  'gaussian_filtered_images/Mild/d5b4705ac2ee.png',
#  'gaussian_filtered_images/Mild/ca1036496659.png',
#  'gaussian_filtered_images/Mild/b56340f472d2.png',
#  'gaussian_filtered_images/Mild/248139c423c4.png',
#  'gaussian_filtered_images/Mild/d66ccb75ada1.png',
#  'gaussian_filtered_images/Mild/d3de0d313d61.png',
#  'gaussian_filtered_images/Mild/cf0575534cec.png',
#  'gaussian_filtered_images/Mild/d1cad012a254.png',
#  'gaussian_filtered_images/Mild/cae51154e1ce.png',
#  'gaussian_filtered_images/Mild/274f5029189b.png',
#  'gaussian_filtered_images/Mild/a3d2a0c4cd17.png',
#  'gaussian_filtered_images/Mild/1e8a1fdee5b9.png',
#  'gaussian_filtered_images/Mild/dbd062558b81.png',
#  'gaussian_filtered_images/Mild/7335a2d43ada.png',
#  'gaussian_filtered_images/Mild/4cae247d9909.png',
#  'gaussian_filtered_images/Mild/27e4c800a449.png',
#  'gaussian_filtered_images/Mild/68332fdcaa70.png',
#  'gaussian_filtered_images/Mild/c8fc0df22999.png',
#  'gaussian_filtered_images/Mild/53704c80f0d8.png',
#  'gaussian_filtered_images/Mild/99ecdb41d5e7.png',
#  'gaussian_filtered_images/Mild/4e0656629d02.png',
#  'gaussian_filtered_images/Mild/194814669fee.png',
#  'gaussian_filtered_images/Mild/84a72e15b23c.png',
#  'gaussian_filtered_images/Mild/a01024054596.png',
#  'gaussian_filtered_images/Mild/99132193eaa0.png',
#  'gaussian_filtered_images/Mild/b6a0e348a01e.png',
#  'gaussian_filtered_images/Mild/90c982cc2d96.png',
#  'gaussian_filtered_images/Mild/7005be54cab1.png',
#  'gaussian_filtered_images/Mild/6ea07d19b4ce.png',
#  'gaussian_filtered_images/Mild/1b329a127307.png',
#  'gaussian_filtered_images/Mild/495255c7492f.png',
#  'gaussian_filtered_images/Mild/6d292ca4c9ad.png',
#  'gaussian_filtered_images/Mild/ca25745942b0.png',
#  'gaussian_filtered_images/Mild/f55e1d2a19e4.png',
#  'gaussian_filtered_images/Mild/513b0a4651fa.png',
#  'gaussian_filtered_images/Mild/17eff993386f.png',
#  'gaussian_filtered_images/Mild/d66b6f333dc7.png',
#  'gaussian_filtered_images/Mild/49386d603494.png',
#  'gaussian_filtered_images/Mild/cab3dfa7962d.png',
#  'gaussian_filtered_images/Mild/677f087cd697.png',
#  'gaussian_filtered_images/Mild/f762c272c522.png',
#  'gaussian_filtered_images/Mild/8676427e4625.png',
#  'gaussian_filtered_images/Mild/e25ccfe38e44.png',
#  'gaussian_filtered_images/Mild/8c2f0f04e1ed.png',
#  'gaussian_filtered_images/Mild/67f5d89da548.png',
#  'gaussian_filtered_images/Mild/c0e15e8e2b46.png',
#  'gaussian_filtered_images/Mild/e26d8718ca58.png',
#  'gaussian_filtered_images/Mild/dd19428c3d29.png',
#  'gaussian_filtered_images/Mild/96a9706b8534.png',
#  'gaussian_filtered_images/Mild/79ce83c07588.png',
#  'gaussian_filtered_images/Mild/ee78ce914066.png',
#  'gaussian_filtered_images/Mild/4393c5bc576a.png',
#  'gaussian_filtered_images/Mild/c027e5482e8c.png',
#  'gaussian_filtered_images/Mild/7f60f2a083d3.png',
#  'gaussian_filtered_images/Mild/fb6b8200b7f8.png',
#  'gaussian_filtered_images/Mild/07a1c7073982.png',
#  'gaussian_filtered_images/Mild/64eb5a79dfdd.png',
#  'gaussian_filtered_images/Mild/b50b30aa6e6c.png',
#  'gaussian_filtered_images/Mild/a95858e052d6.png',
#  'gaussian_filtered_images/Mild/c0f15fe3b4b7.png',
#  'gaussian_filtered_images/Mild/8a25a080f28f.png',
#  'gaussian_filtered_images/Mild/58ccba7eec9c.png',
#  'gaussian_filtered_images/Mild/4e82c3c8d31f.png',
#  'gaussian_filtered_images/Mild/c1ebe785503a.png',
#  'gaussian_filtered_images/Mild/d801c0a66738.png',
#  'gaussian_filtered_images/Mild/8ef2eb8c51c4.png',
#  'gaussian_filtered_images/Mild/cd5714db652d.png',
#  'gaussian_filtered_images/Mild/13ab8db8c700.png',
#  'gaussian_filtered_images/Mild/bc73ce76ec43.png',
#  'gaussian_filtered_images/Mild/0eb52045349f.png',
#  'gaussian_filtered_images/Mild/53f6c1c65c04.png',
#  'gaussian_filtered_images/Mild/b94c58d063bf.png',
#  'gaussian_filtered_images/Mild/33105f9b3a04.png',
#  'gaussian_filtered_images/Mild/36677b70b1ef.png',
#  'gaussian_filtered_images/Mild/e07045d7c5f7.png',
#  'gaussian_filtered_images/Mild/ec4649213ccf.png',
#  'gaussian_filtered_images/Mild/0dc031c94225.png',
#  'gaussian_filtered_images/Mild/eed4afc8ec83.png',
#  'gaussian_filtered_images/Mild/665ce639a331.png',
#  'gaussian_filtered_images/Mild/22325552a4e3.png',
#  'gaussian_filtered_images/Mild/12ce6a1a1f31.png',
#  'gaussian_filtered_images/Mild/fd62bd0db4f1.png',
#  'gaussian_filtered_images/Mild/5efa24b03d5e.png',
#  'gaussian_filtered_images/Mild/fe2df69676cf.png',
#  'gaussian_filtered_images/Mild/c4a8f2fcf6e8.png',
#  'gaussian_filtered_images/Mild/2a8a9e957a6c.png',
#  'gaussian_filtered_images/Mild/22098b1fe461.png',
#  'gaussian_filtered_images/Mild/365f8c01d994.png',
#  'gaussian_filtered_images/Mild/7ea756985353.png',
#  'gaussian_filtered_images/Mild/849a91e9ab28.png',
#  'gaussian_filtered_images/Mild/94b1d8ad35ec.png',
#  'gaussian_filtered_images/Mild/22a6da005395.png',
#  'gaussian_filtered_images/Mild/587146a55885.png',
#  'gaussian_filtered_images/Mild/45e4b7eada54.png',
#  'gaussian_filtered_images/Mild/05a5183c92d0.png',
#  'gaussian_filtered_images/Mild/ae8472f8d310.png',
#  'gaussian_filtered_images/Mild/5b0e53f53ef3.png',
#  'gaussian_filtered_images/Mild/98fbe56dcc2c.png',
#  'gaussian_filtered_images/Mild/c9485c38fdd5.png',
#  'gaussian_filtered_images/Mild/6cdd0f985270.png',
#  'gaussian_filtered_images/Mild/73881f55a3ec.png',
#  'gaussian_filtered_images/Mild/01b3aed3ed4c.png',
#  'gaussian_filtered_images/Mild/04ac765f91a1.png',
#  'gaussian_filtered_images/Mild/b22354b5f94b.png',
#  'gaussian_filtered_images/Mild/d4f32b9c07df.png',
#  'gaussian_filtered_images/Mild/35d6c4c50072.png',
#  'gaussian_filtered_images/Mild/bb783d8e496f.png',
#  'gaussian_filtered_images/Mild/e9ff9352ccb3.png',
#  'gaussian_filtered_images/Mild/0f495d87656a.png',
#  'gaussian_filtered_images/Mild/abdb365cacbc.png',
#  'gaussian_filtered_images/Mild/af133a85ea0c.png',
#  'gaussian_filtered_images/Mild/8ff863f8874f.png',
#  'gaussian_filtered_images/Mild/bacfb1029f6b.png',
#  'gaussian_filtered_images/Mild/f6f7dba7104d.png',
#  'gaussian_filtered_images/Mild/40e9b5630438.png',
#  'gaussian_filtered_images/Mild/4661006f3ba6.png',
#  'gaussian_filtered_images/Mild/382752f6694a.png',
#  'gaussian_filtered_images/Mild/a2696f444ecb.png',
#  'gaussian_filtered_images/Mild/eba3acc42197.png',
#  'gaussian_filtered_images/Mild/8bc6716c2238.png',
#  'gaussian_filtered_images/Mild/cfd1bd0fcbb4.png',
#  'gaussian_filtered_images/Mild/ababe19ed448.png',
#  'gaussian_filtered_images/Mild/c102db7634d8.png',
#  'gaussian_filtered_images/Mild/33ffddea8c6e.png',
#  'gaussian_filtered_images/Mild/0369f3efe69b.png',
#  'gaussian_filtered_images/Mild/6b00cb764237.png',
#  'gaussian_filtered_images/Mild/821789e9053f.png',
#  'gaussian_filtered_images/Mild/a47432cd41e7.png',
#  'gaussian_filtered_images/Mild/e580676516b0.png',
#  'gaussian_filtered_images/Mild/107aea0d9289.png',
#  'gaussian_filtered_images/Mild/4dd9d29eae5d.png',
#  'gaussian_filtered_images/Mild/12e3f5f2cb17.png',
#  'gaussian_filtered_images/Mild/655cafb4c932.png',
#  'gaussian_filtered_images/Mild/5b72ff04333d.png',
#  'gaussian_filtered_images/Mild/5a091e8cd95c.png',
#  'gaussian_filtered_images/Mild/50840c36f0b4.png',
#  'gaussian_filtered_images/Mild/7ccb267fd394.png',
#  'gaussian_filtered_images/Mild/b576c5269ad1.png',
#  'gaussian_filtered_images/Mild/531b39880c32.png',
#  'gaussian_filtered_images/Mild/cc12453ea915.png',
#  'gaussian_filtered_images/Mild/cc9270f06b65.png',
#  'gaussian_filtered_images/Mild/7a3ea1779b13.png',
#  'gaussian_filtered_images/Mild/8114d6a160df.png',
#  'gaussian_filtered_images/Mild/a3ad6c2db6f1.png',
#  'gaussian_filtered_images/Mild/6028a575dc27.png',
#  'gaussian_filtered_images/Mild/4da2961e62fe.png',
#  'gaussian_filtered_images/Mild/f5650eb52640.png',
#  'gaussian_filtered_images/Mild/494fc9c745a3.png',
#  'gaussian_filtered_images/Mild/a75bab2463d4.png',
#  'gaussian_filtered_images/Mild/fe674c2f73f5.png',
#  'gaussian_filtered_images/Mild/30941b65348b.png',
#  'gaussian_filtered_images/Mild/5347b4c8e9b3.png',
#  'gaussian_filtered_images/Mild/d06ccd0cf4b8.png',
#  'gaussian_filtered_images/Mild/64678182d8a8.png',
#  'gaussian_filtered_images/Mild/61bbe8db6f3a.png',
#  'gaussian_filtered_images/Mild/76e589911303.png',
#  'gaussian_filtered_images/Mild/19722bff5a09.png',
#  'gaussian_filtered_images/Mild/36041171f441.png',
#  'gaussian_filtered_images/Mild/3044022c6969.png',
#  'gaussian_filtered_images/Mild/ead23cc922ed.png',
#  'gaussian_filtered_images/Mild/e2a233493b90.png',
#  'gaussian_filtered_images/Mild/25e9fd872182.png',
#  'gaussian_filtered_images/Mild/bf18ff30a8f6.png',
#  'gaussian_filtered_images/Mild/0684311afdfc.png',
#  'gaussian_filtered_images/Mild/d85588ff2ebd.png',
#  'gaussian_filtered_images/Mild/4c129470cec4.png',
#  'gaussian_filtered_images/Mild/f47a2a4a0411.png',
#  'gaussian_filtered_images/Mild/07929d32b5b3.png',
#  'gaussian_filtered_images/Mild/3ee17aa12e46.png',
#  'gaussian_filtered_images/Mild/756b0d6488bb.png',
#  'gaussian_filtered_images/Mild/6b07971c3bf6.png',
#  'gaussian_filtered_images/Mild/1c3a6b4449e9.png',
#  'gaussian_filtered_images/Mild/38b9bb961847.png',
#  'gaussian_filtered_images/Mild/fdd18ccbbdc5.png',
#  'gaussian_filtered_images/Mild/3b73a3a4a734.png',
#  'gaussian_filtered_images/Mild/1116271db4ea.png',
#  'gaussian_filtered_images/Mild/18b06f56ab27.png',
#  'gaussian_filtered_images/Mild/31cb39681f6a.png',
#  'gaussian_filtered_images/Mild/65e51e18242b.png',
#  'gaussian_filtered_images/Mild/0d310aba6373.png',
#  'gaussian_filtered_images/Mild/613bacb35c05.png',
#  'gaussian_filtered_images/Mild/ca63fe4f4b52.png',
#  'gaussian_filtered_images/Mild/00cb6555d108.png',
#  'gaussian_filtered_images/Mild/ca7140ecf389.png',
#  'gaussian_filtered_images/Mild/b07bc463b718.png',
#  'gaussian_filtered_images/Mild/7116128c65ab.png',
#  'gaussian_filtered_images/Mild/92d9e9f08709.png',
#  'gaussian_filtered_images/Mild/5cab3ef4b31c.png',
#  'gaussian_filtered_images/Mild/29b52f64d2db.png',
#  'gaussian_filtered_images/Mild/89d9c071a56f.png',
#  'gaussian_filtered_images/Mild/eeb231c3ef1f.png']

# %%
glob('gaussian_filtered_images/Mild/*[0-9].png')
# Out:
# ['gaussian_filtered_images/Mild/d85d052900b4.png',
#  'gaussian_filtered_images/Mild/6298468d7d75.png',
#  'gaussian_filtered_images/Mild/58184d6fd087.png',
#  'gaussian_filtered_images/Mild/03e25101e8e8.png',
#  'gaussian_filtered_images/Mild/80a02014b418.png',
#  'gaussian_filtered_images/Mild/76be29bb30b2.png',
#  'gaussian_filtered_images/Mild/5712e2aa73a2.png',
#  'gaussian_filtered_images/Mild/db4ed1e07aa3.png',
#  'gaussian_filtered_images/Mild/8f2996b8d855.png',
#  'gaussian_filtered_images/Mild/6c6efb6b1358.png',
#  'gaussian_filtered_images/Mild/2ecbc2e3f239.png',
#  'gaussian_filtered_images/Mild/5090917a2676.png',
#  'gaussian_filtered_images/Mild/4ecd1fdd1435.png',
#  'gaussian_filtered_images/Mild/172df1330a60.png',
#  'gaussian_filtered_images/Mild/c1e6fa1ad314.png',
#  'gaussian_filtered_images/Mild/1a03a7970337.png',
#  'gaussian_filtered_images/Mild/0124dffecf29.png',
#  'gaussian_filtered_images/Mild/3f73c91b7e32.png',
#  'gaussian_filtered_images/Mild/da1fb35f5df9.png',
#  'gaussian_filtered_images/Mild/2d9d97a6e713.png',
#  'gaussian_filtered_images/Mild/a8c950a99107.png',
#  'gaussian_filtered_images/Mild/33b893e18eb3.png',
#  'gaussian_filtered_images/Mild/7b20210d9120.png',
#  'gaussian_filtered_images/Mild/7ef5ff774a48.png',
#  'gaussian_filtered_images/Mild/b7278b4f2448.png',
#  'gaussian_filtered_images/Mild/b1197f2cc9b3.png',
#  'gaussian_filtered_images/Mild/a00b4cb250a7.png',
#  'gaussian_filtered_images/Mild/977e1ca77653.png',
#  'gaussian_filtered_images/Mild/8a01daa423f7.png',
#  'gaussian_filtered_images/Mild/cd45bfa07d41.png',
#  'gaussian_filtered_images/Mild/a8582e346df0.png',
#  'gaussian_filtered_images/Mild/086d41d17da8.png',
#  'gaussian_filtered_images/Mild/71c1a3cdbe47.png',
#  'gaussian_filtered_images/Mild/4a213b405ee4.png',
#  'gaussian_filtered_images/Mild/6377e23928f6.png',
#  'gaussian_filtered_images/Mild/a8c54e2a4b79.png',
#  'gaussian_filtered_images/Mild/fea14b3d44b0.png',
#  'gaussian_filtered_images/Mild/c0968d41eb93.png',
#  'gaussian_filtered_images/Mild/2994f17f58a5.png',
#  'gaussian_filtered_images/Mild/3461dc601cc2.png',
#  'gaussian_filtered_images/Mild/ad3fc5076852.png',
#  'gaussian_filtered_images/Mild/1d674e2e32e0.png',
#  'gaussian_filtered_images/Mild/52ae917fcea4.png',
#  'gaussian_filtered_images/Mild/94111ed3d276.png',
#  'gaussian_filtered_images/Mild/66cd9c28e636.png',
#  'gaussian_filtered_images/Mild/cb2f3c5d71a7.png',
#  'gaussian_filtered_images/Mild/93be637084a2.png',
#  'gaussian_filtered_images/Mild/6165081b9021.png',
#  'gaussian_filtered_images/Mild/358d2224de73.png',
#  'gaussian_filtered_images/Mild/3c726de3ee90.png',
#  'gaussian_filtered_images/Mild/28f98cfe3858.png',
#  'gaussian_filtered_images/Mild/259d30f693b6.png',
#  'gaussian_filtered_images/Mild/f0c13be90519.png',
#  'gaussian_filtered_images/Mild/ea15a290eb96.png',
#  'gaussian_filtered_images/Mild/f481f76a6b75.png',
#  'gaussian_filtered_images/Mild/59e5212f7139.png',
#  'gaussian_filtered_images/Mild/ca6842bfcbc9.png',
#  'gaussian_filtered_images/Mild/c40976189f22.png',
#  'gaussian_filtered_images/Mild/77a9538b8362.png',
#  'gaussian_filtered_images/Mild/ef8109305128.png',
#  'gaussian_filtered_images/Mild/4aa07d720638.png',
#  'gaussian_filtered_images/Mild/a77dbec966d4.png',
#  'gaussian_filtered_images/Mild/bb9a3d835a94.png',
#  'gaussian_filtered_images/Mild/d567a1a22d33.png',
#  'gaussian_filtered_images/Mild/4fa26d065ad3.png',
#  'gaussian_filtered_images/Mild/1c0cf251b426.png',
#  'gaussian_filtered_images/Mild/d0d59ed675b5.png',
#  'gaussian_filtered_images/Mild/3de8ad4151e1.png',
#  'gaussian_filtered_images/Mild/ad1f7445b1a8.png',
#  'gaussian_filtered_images/Mild/595446774178.png',
#  'gaussian_filtered_images/Mild/49c5e7f6b8d2.png',
#  'gaussian_filtered_images/Mild/0dce95217626.png',
#  'gaussian_filtered_images/Mild/cf603a9ef2d5.png',
#  'gaussian_filtered_images/Mild/a5a2a7003d60.png',
#  'gaussian_filtered_images/Mild/a7ec056502e7.png',
#  'gaussian_filtered_images/Mild/2f2e1949ad56.png',
#  'gaussian_filtered_images/Mild/51131b48f9d4.png',
#  'gaussian_filtered_images/Mild/b640e3bdff75.png',
#  'gaussian_filtered_images/Mild/ca30a97e9d13.png',
#  'gaussian_filtered_images/Mild/0a61bddab956.png',
#  'gaussian_filtered_images/Mild/c96f743915b5.png',
#  'gaussian_filtered_images/Mild/f72ef9ceeaa8.png',
#  'gaussian_filtered_images/Mild/9a3109657ac1.png',
#  'gaussian_filtered_images/Mild/5b068765e846.png',
#  'gaussian_filtered_images/Mild/c7b622ec8104.png',
#  'gaussian_filtered_images/Mild/bebb3f167654.png',
#  'gaussian_filtered_images/Mild/578109578b46.png',
#  'gaussian_filtered_images/Mild/523b3f0fc646.png',
#  'gaussian_filtered_images/Mild/c739ff9580d3.png',
#  'gaussian_filtered_images/Mild/78bcdffb8785.png',
#  'gaussian_filtered_images/Mild/6762b2b48ea5.png',
#  'gaussian_filtered_images/Mild/c56e65f74187.png',
#  'gaussian_filtered_images/Mild/38e0e28d35d3.png',
#  'gaussian_filtered_images/Mild/b17f0b81dab3.png',
#  'gaussian_filtered_images/Mild/545df1bbcd61.png',
#  'gaussian_filtered_images/Mild/101b9ebfc720.png',
#  'gaussian_filtered_images/Mild/4c3c1ed09771.png',
#  'gaussian_filtered_images/Mild/4e6071b73120.png',
#  'gaussian_filtered_images/Mild/a28bfb772f50.png',
#  'gaussian_filtered_images/Mild/059bc89df7f4.png',
#  'gaussian_filtered_images/Mild/db690e2d02f8.png',
#  'gaussian_filtered_images/Mild/f7fec8935126.png',
#  'gaussian_filtered_images/Mild/e96bd80a8a53.png',
#  'gaussian_filtered_images/Mild/35aa7f5c2ec0.png',
#  'gaussian_filtered_images/Mild/55eac26bd383.png',
#  'gaussian_filtered_images/Mild/ca1036496659.png',
#  'gaussian_filtered_images/Mild/b56340f472d2.png',
#  'gaussian_filtered_images/Mild/248139c423c4.png',
#  'gaussian_filtered_images/Mild/d66ccb75ada1.png',
#  'gaussian_filtered_images/Mild/d3de0d313d61.png',
#  'gaussian_filtered_images/Mild/d1cad012a254.png',
#  'gaussian_filtered_images/Mild/a3d2a0c4cd17.png',
#  'gaussian_filtered_images/Mild/1e8a1fdee5b9.png',
#  'gaussian_filtered_images/Mild/dbd062558b81.png',
#  'gaussian_filtered_images/Mild/4cae247d9909.png',
#  'gaussian_filtered_images/Mild/27e4c800a449.png',
#  'gaussian_filtered_images/Mild/68332fdcaa70.png',
#  'gaussian_filtered_images/Mild/c8fc0df22999.png',
#  'gaussian_filtered_images/Mild/53704c80f0d8.png',
#  'gaussian_filtered_images/Mild/99ecdb41d5e7.png',
#  'gaussian_filtered_images/Mild/4e0656629d02.png',
#  'gaussian_filtered_images/Mild/a01024054596.png',
#  'gaussian_filtered_images/Mild/99132193eaa0.png',
#  'gaussian_filtered_images/Mild/90c982cc2d96.png',
#  'gaussian_filtered_images/Mild/7005be54cab1.png',
#  'gaussian_filtered_images/Mild/1b329a127307.png',
#  'gaussian_filtered_images/Mild/ca25745942b0.png',
#  'gaussian_filtered_images/Mild/f55e1d2a19e4.png',
#  'gaussian_filtered_images/Mild/d66b6f333dc7.png',
#  'gaussian_filtered_images/Mild/49386d603494.png',
#  'gaussian_filtered_images/Mild/677f087cd697.png',
#  'gaussian_filtered_images/Mild/f762c272c522.png',
#  'gaussian_filtered_images/Mild/8676427e4625.png',
#  'gaussian_filtered_images/Mild/e25ccfe38e44.png',
#  'gaussian_filtered_images/Mild/67f5d89da548.png',
#  'gaussian_filtered_images/Mild/c0e15e8e2b46.png',
#  'gaussian_filtered_images/Mild/e26d8718ca58.png',
#  'gaussian_filtered_images/Mild/dd19428c3d29.png',
#  'gaussian_filtered_images/Mild/96a9706b8534.png',
#  'gaussian_filtered_images/Mild/79ce83c07588.png',
#  'gaussian_filtered_images/Mild/ee78ce914066.png',
#  'gaussian_filtered_images/Mild/7f60f2a083d3.png',
#  'gaussian_filtered_images/Mild/fb6b8200b7f8.png',
#  'gaussian_filtered_images/Mild/07a1c7073982.png',
#  'gaussian_filtered_images/Mild/a95858e052d6.png',
#  'gaussian_filtered_images/Mild/c0f15fe3b4b7.png',
#  'gaussian_filtered_images/Mild/d801c0a66738.png',
#  'gaussian_filtered_images/Mild/8ef2eb8c51c4.png',
#  'gaussian_filtered_images/Mild/13ab8db8c700.png',
#  'gaussian_filtered_images/Mild/bc73ce76ec43.png',
#  'gaussian_filtered_images/Mild/53f6c1c65c04.png',
#  'gaussian_filtered_images/Mild/33105f9b3a04.png',
#  'gaussian_filtered_images/Mild/e07045d7c5f7.png',
#  'gaussian_filtered_images/Mild/0dc031c94225.png',
#  'gaussian_filtered_images/Mild/eed4afc8ec83.png',
#  'gaussian_filtered_images/Mild/665ce639a331.png',
#  'gaussian_filtered_images/Mild/22325552a4e3.png',
#  'gaussian_filtered_images/Mild/12ce6a1a1f31.png',
#  'gaussian_filtered_images/Mild/fd62bd0db4f1.png',
#  'gaussian_filtered_images/Mild/c4a8f2fcf6e8.png',
#  'gaussian_filtered_images/Mild/22098b1fe461.png',
#  'gaussian_filtered_images/Mild/365f8c01d994.png',
#  'gaussian_filtered_images/Mild/7ea756985353.png',
#  'gaussian_filtered_images/Mild/849a91e9ab28.png',
#  'gaussian_filtered_images/Mild/22a6da005395.png',
#  'gaussian_filtered_images/Mild/587146a55885.png',
#  'gaussian_filtered_images/Mild/45e4b7eada54.png',
#  'gaussian_filtered_images/Mild/05a5183c92d0.png',
#  'gaussian_filtered_images/Mild/ae8472f8d310.png',
#  'gaussian_filtered_images/Mild/5b0e53f53ef3.png',
#  'gaussian_filtered_images/Mild/c9485c38fdd5.png',
#  'gaussian_filtered_images/Mild/6cdd0f985270.png',
#  'gaussian_filtered_images/Mild/04ac765f91a1.png',
#  'gaussian_filtered_images/Mild/35d6c4c50072.png',
#  'gaussian_filtered_images/Mild/e9ff9352ccb3.png',
#  'gaussian_filtered_images/Mild/40e9b5630438.png',
#  'gaussian_filtered_images/Mild/4661006f3ba6.png',
#  'gaussian_filtered_images/Mild/eba3acc42197.png',
#  'gaussian_filtered_images/Mild/8bc6716c2238.png',
#  'gaussian_filtered_images/Mild/cfd1bd0fcbb4.png',
#  'gaussian_filtered_images/Mild/ababe19ed448.png',
#  'gaussian_filtered_images/Mild/c102db7634d8.png',
#  'gaussian_filtered_images/Mild/6b00cb764237.png',
#  'gaussian_filtered_images/Mild/a47432cd41e7.png',
#  'gaussian_filtered_images/Mild/e580676516b0.png',
#  'gaussian_filtered_images/Mild/107aea0d9289.png',
#  'gaussian_filtered_images/Mild/12e3f5f2cb17.png',
#  'gaussian_filtered_images/Mild/655cafb4c932.png',
#  'gaussian_filtered_images/Mild/50840c36f0b4.png',
#  'gaussian_filtered_images/Mild/7ccb267fd394.png',
#  'gaussian_filtered_images/Mild/b576c5269ad1.png',
#  'gaussian_filtered_images/Mild/531b39880c32.png',
#  'gaussian_filtered_images/Mild/cc12453ea915.png',
#  'gaussian_filtered_images/Mild/cc9270f06b65.png',
#  'gaussian_filtered_images/Mild/7a3ea1779b13.png',
#  'gaussian_filtered_images/Mild/a3ad6c2db6f1.png',
#  'gaussian_filtered_images/Mild/6028a575dc27.png',
#  'gaussian_filtered_images/Mild/f5650eb52640.png',
#  'gaussian_filtered_images/Mild/494fc9c745a3.png',
#  'gaussian_filtered_images/Mild/a75bab2463d4.png',
#  'gaussian_filtered_images/Mild/fe674c2f73f5.png',
#  'gaussian_filtered_images/Mild/5347b4c8e9b3.png',
#  'gaussian_filtered_images/Mild/d06ccd0cf4b8.png',
#  'gaussian_filtered_images/Mild/64678182d8a8.png',
#  'gaussian_filtered_images/Mild/76e589911303.png',
#  'gaussian_filtered_images/Mild/19722bff5a09.png',
#  'gaussian_filtered_images/Mild/36041171f441.png',
#  'gaussian_filtered_images/Mild/3044022c6969.png',
#  'gaussian_filtered_images/Mild/e2a233493b90.png',
#  'gaussian_filtered_images/Mild/25e9fd872182.png',
#  'gaussian_filtered_images/Mild/bf18ff30a8f6.png',
#  'gaussian_filtered_images/Mild/4c129470cec4.png',
#  'gaussian_filtered_images/Mild/f47a2a4a0411.png',
#  'gaussian_filtered_images/Mild/07929d32b5b3.png',
#  'gaussian_filtered_images/Mild/3ee17aa12e46.png',
#  'gaussian_filtered_images/Mild/6b07971c3bf6.png',
#  'gaussian_filtered_images/Mild/1c3a6b4449e9.png',
#  'gaussian_filtered_images/Mild/38b9bb961847.png',
#  'gaussian_filtered_images/Mild/fdd18ccbbdc5.png',
#  'gaussian_filtered_images/Mild/3b73a3a4a734.png',
#  'gaussian_filtered_images/Mild/18b06f56ab27.png',
#  'gaussian_filtered_images/Mild/0d310aba6373.png',
#  'gaussian_filtered_images/Mild/613bacb35c05.png',
#  'gaussian_filtered_images/Mild/ca63fe4f4b52.png',
#  'gaussian_filtered_images/Mild/00cb6555d108.png',
#  'gaussian_filtered_images/Mild/ca7140ecf389.png',
#  'gaussian_filtered_images/Mild/b07bc463b718.png',
#  'gaussian_filtered_images/Mild/92d9e9f08709.png']

# %% [markdown]
# DataFrame

# %%
import numpy as np
all_png_list = glob('gaussian_filtered_images/*/*.png')
type_list = [p.split('/')[1] for p in all_png_list]
print(np.unique(type_list))
extension_list = [p.split('.')[-1] for p in all_png_list]
print(np.unique(extension_list))
# Out:
# ['Mild' 'Moderate' 'No_DR' 'Proliferate_DR' 'Severe']
# ['png']

# %%
import pandas as pd
df = pd.DataFrame({'filepath': all_png_list, 'type': type_list, 'extension': extension_list})
print(type(df))
print(len(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 3662
#                                                filepath      type extension
# 0     gaussian_filtered_images/Moderate/a15590a7d774...  Moderate       png
# 1     gaussian_filtered_images/Moderate/1124ffcd76c2...  Moderate       png
# 2     gaussian_filtered_images/Moderate/b89938407ee6...  Moderate       png
# 3     gaussian_filtered_images/Moderate/1438288bb2e1...  Moderate       png
# 4     gaussian_filtered_images/Moderate/7c52fe73e748...  Moderate       png
# ...                                                 ...       ...       ...
# 3657   gaussian_filtered_images/Severe/d035c2bd9104.png    Severe       png
# 3658   gaussian_filtered_images/Severe/0104b032c141.png    Severe       png
# 3659   gaussian_filtered_images/Severe/6a244e855d0e.png    Severe       png
# 3660   gaussian_filtered_images/Severe/1623e8e3adc4.png    Severe       png
# 3661   gaussian_filtered_images/Severe/72595230840c.png    Severe       png
#
# [3662 rows x 3 columns]

# %%
df['type'].value_counts()
# Out:
# No_DR             1805
# Moderate           999
# Mild               370
# Proliferate_DR     295
# Severe             193
# Name: type, dtype: int64

# %%
import seaborn as sns
# %matplotlib inline
sns.set()
sns.countplot(x='type', data=df)
