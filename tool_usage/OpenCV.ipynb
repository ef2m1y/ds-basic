# %%
# docker exec -it {name} bash

# apt-get update
# apt-get install -y libsm6 libxext6 libxrender-dev libglib2.0-0

# apt-get update && apt-get upgrade -y
# sudo apt-get install libgl1-mesa-dev

# pip install opencv-python

# %%
import cv2
cv2.__file__
# Out:
# '/opt/anaconda3/lib/python3.7/site-packages/cv2/__init__.py'

# %%
lenna = cv2.imread('lenna.png')
print(type(lenna))
print("(h[px], w[px], channel[BGR=3channels]):{}".format(lenna.shape))
# Out:
# <class 'numpy.ndarray'>
# (h[px], w[px], channel[BGR=3channels]):(220, 220, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(lenna)

# %% [markdown]
# - Red <-> Brue
#     - OpenCV: BGR
#     - matplotlib: RGB

# %%
# convert color space
lenna_rgb = cv2.cvtColor(lenna, cv2.COLOR_BGR2RGB)
plt.imshow(lenna_rgb)
